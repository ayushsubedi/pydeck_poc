# %%
from keplergl import KeplerGl
import pandas as pd

# %%
## dataset
df = pd.read_csv('dataset/nyc_dataset.csv')

# %%
# Sample map
map_1 = KeplerGl(height=400)
map_1
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl()

# %%
df.head()
# Out:
#           id  vendor_id      pickup_datetime  passenger_count  \
# 0  id3004672          1  2016-06-30 23:59:58                1
# 1  id3505355          1  2016-06-30 23:59:53                1
# 2  id1217141          1  2016-06-30 23:59:47                1
# 3  id2150126          2  2016-06-30 23:59:41                1
# 4  id1598245          1  2016-06-30 23:59:33                1
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.988129        40.732029         -73.990173         40.756680
# 1        -73.964203        40.679993         -73.959808         40.655403
# 2        -73.997437        40.737583         -73.986160         40.729523
# 3        -73.956070        40.771900         -73.986427         40.730469
# 4        -73.970215        40.761475         -73.961510         40.755890
#
#   store_and_fwd_flag
# 0                  N
# 1                  N
# 2                  N
# 3                  N
# 4                  N

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 625134 entries, 0 to 625133
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  625134 non-null  object
#  1   vendor_id           625134 non-null  int64
#  2   pickup_datetime     625134 non-null  object
#  3   passenger_count     625134 non-null  int64
#  4   pickup_longitude    625134 non-null  float64
#  5   pickup_latitude     625134 non-null  float64
#  6   dropoff_longitude   625134 non-null  float64
#  7   dropoff_latitude    625134 non-null  float64
#  8   store_and_fwd_flag  625134 non-null  object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 42.9+ MB

# %%
map_2 = KeplerGl(data={'data_1':df}, height=400)
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter

# %%
map_2
# Out:
# KeplerGl(data={'data_1':                id  vendor_id      pickup_datetime  passenger_count  \
# 0       id30046…

# %%
config= {
  "version": "v1",
  "config": {
    "visState": {
      "filters": [
        {
          "dataId": [
            "data_1"
          ],
          "id": "9ibidlq",
          "name": [
            "pickup_datetime"
          ],
          "type": "timeRange",
          "value": [
            1451850067000,
            1466913157000
          ],
          "enlarged": False,
          "plotType": "histogram",
          "yAxis": None
        },
        {
          "dataId": [
            "data_1"
          ],
          "id": "695c9x86s",
          "name": [
            "pickup_datetime"
          ],
          "type": "timeRange",
          "value": [
            1465627680600,
            1465974600680
          ],
          "enlarged": True,
          "plotType": "histogram",
          "yAxis": None
        },
        {
          "dataId": [
            "data_1"
          ],
          "id": "no6q4yp9l",
          "name": [],
          "type": None,
          "value": None,
          "enlarged": False,
          "plotType": "histogram",
          "yAxis": None
        }
      ],
      "layers": [
        {
          "id": "hnu1vxo",
          "type": "point",
          "config": {
            "dataId": "data_1",
            "label": "pickup",
            "color": [
              18,
              147,
              154
            ],
            "columns": {
              "lat": "pickup_latitude",
              "lng": "pickup_longitude",
              "altitude": None
            },
            "isVisible": False,
            "visConfig": {
              "radius": 10,
              "fixedRadius": False,
              "opacity": 0.8,
              "outline": False,
              "thickness": 2,
              "strokeColor": None,
              "colorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "strokeColorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "radiusRange": [
                0,
                50
              ],
              "filled": True
            },
            "hidden": False,
            "textLabel": [
              {
                "field": None,
                "color": [
                  255,
                  255,
                  255
                ],
                "size": 18,
                "offset": [
                  0,
                  0
                ],
                "anchor": "start",
                "alignment": "center"
              }
            ]
          },
          "visualChannels": {
            "colorField": None,
            "colorScale": "quantile",
            "strokeColorField": None,
            "strokeColorScale": "quantile",
            "sizeField": None,
            "sizeScale": "linear"
          }
        },
        {
          "id": "xyaflnq",
          "type": "point",
          "config": {
            "dataId": "data_1",
            "label": "dropoff",
            "color": [
              221,
              178,
              124
            ],
            "columns": {
              "lat": "dropoff_latitude",
              "lng": "dropoff_longitude",
              "altitude": None
            },
            "isVisible": False,
            "visConfig": {
              "radius": 10,
              "fixedRadius": False,
              "opacity": 0.8,
              "outline": False,
              "thickness": 2,
              "strokeColor": None,
              "colorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "strokeColorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "radiusRange": [
                0,
                50
              ],
              "filled": True
            },
            "hidden": False,
            "textLabel": [
              {
                "field": None,
                "color": [
                  255,
                  255,
                  255
                ],
                "size": 18,
                "offset": [
                  0,
                  0
                ],
                "anchor": "start",
                "alignment": "center"
              }
            ]
          },
          "visualChannels": {
            "colorField": None,
            "colorScale": "quantile",
            "strokeColorField": None,
            "strokeColorScale": "quantile",
            "sizeField": None,
            "sizeScale": "linear"
          }
        },
        {
          "id": "dct214f",
          "type": "arc",
          "config": {
            "dataId": "data_1",
            "label": "pickup -> dropoff arc",
            "color": [
              64,
              100,
              34
            ],
            "columns": {
              "lat0": "pickup_latitude",
              "lng0": "pickup_longitude",
              "lat1": "dropoff_latitude",
              "lng1": "dropoff_longitude"
            },
            "isVisible": True,
            "visConfig": {
              "opacity": 0.8,
              "thickness": 1,
              "colorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "sizeRange": [
                0,
                10
              ],
              "targetColor": [
                187,
                0,
                0
              ]
            },
            "hidden": False,
            "textLabel": [
              {
                "field": None,
                "color": [
                  255,
                  255,
                  255
                ],
                "size": 18,
                "offset": [
                  0,
                  0
                ],
                "anchor": "start",
                "alignment": "center"
              }
            ]
          },
          "visualChannels": {
            "colorField": None,
            "colorScale": "quantile",
            "sizeField": None,
            "sizeScale": "linear"
          }
        }
      ],
      "interactionConfig": {
        "tooltip": {
          "fieldsToShow": {
            "data_1": [
              {
                "name": "id",
                "format": None
              },
              {
                "name": "vendor_id",
                "format": None
              },
              {
                "name": "pickup_datetime",
                "format": None
              },
              {
                "name": "passenger_count",
                "format": None
              },
              {
                "name": "store_and_fwd_flag",
                "format": None
              }
            ]
          },
          "compareMode": False,
          "compareType": "absolute",
          "enabled": False
        },
        "brush": {
          "size": 0.6,
          "enabled": False
        },
        "geocoder": {
          "enabled": False
        },
        "coordinate": {
          "enabled": False
        }
      },
      "layerBlending": "normal",
      "splitMaps": [],
      "animationConfig": {
        "currentTime": None,
        "speed": 1
      }
    },
    "mapState": {
      "bearing": 24,
      "dragRotate": True,
      "latitude": 40.65331045198191,
      "longitude": -74.03283781861067,
      "pitch": 50,
      "zoom": 10.235611168579341,
      "isSplit": False
    },
    "mapStyle": {
      "styleType": "light",
      "topLayerGroups": {},
      "visibleLayerGroups": {
        "label": True,
        "road": True,
        "border": False,
        "building": True,
        "water": True,
        "land": True,
        "3d building": False
      },
      "threeDBuildingColor": [
        9.665468314072013,
        17.18305478057247,
        31.1442867897876
      ],
      "mapStyles": {}
    }
  }
}

# %%
map_3 = KeplerGl(data={'data_1':df}, config=config, height=400)
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter

# %%
map_3
# Out:
# KeplerGl(config={'version': 'v1', 'config': {'visState': {'filters': [{'dataId': ['data_1'], 'id': '9ibidlq', …
